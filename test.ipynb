# %%
from PyPDF2 import PdfReader

# %%
pdf_path = r"C:\Users\furth\OneDrive\Desktop\Resume Screening\resumes\Abdul Salam Azadh.pdf"

# %%
reader = PdfReader(pdf_path)
text = ""
for page in reader.pages:
    text += page.extract_text()
    
print(text)
# Out:
# ABDUL SALAM AZADH Z
# TECHNOLOGY ANALYST  | BANGALOR E, KARNATAKA.
#  abdulsalamazadhz@gmail.com   +91 7397799366   linkedin/abdulsalamazadh   github/abdulsalamazadh
#
#
# SUMMARY :
# Data Analyst with 2+ years of experience in SQL, Python, Power BI, Data Cleaning, and Business Insights. Skilled at analysing
# large datasets, building automated reporting pipelines, and delivering dashboards that support data -driven decisions. Worked
# with global stakeholder Rolls -Royce, delivering high -accuracy KPIs, operational insights, and trend analysis that improved
# decision -making and reduced inefficiencies. Strong in EDA, data modelling, cross -functional collaboration, and generating clear,
# actionabl e insights
# SKILLS:
# Data Analytics: SQL, Python (Pandas, NumPy), EDA, KPI Tracking, Trend Analysis .
# Visualization & BI: Power BI, Plotly, Seaborn, Matplotlib, Streamlit.
# Databases : PostgreSQL, MongoDB .
# ...
